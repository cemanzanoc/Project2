# %%
import pandas as pd
import cleaning_functions as cf

# %%
df_final_demo = pd.read_csv("df_final_demo.txt", delimiter=",")

# %%
df_final_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df_final_demo.isna().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
df_final_demo = df_final_demo.dropna()
df_final_demo.isna().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# dtype: int64

# %%
df_final_demo_clean = cf.handle_duplicates(df_final_demo)
# Out:
# Number of duplicated rows before cleaning: 0
# Number of duplicated rows after cleaning: 0

# %%
df_final_demo_clean.dtypes
# Out:
# client_id             int64
# clnt_tenure_yr      float64
# clnt_tenure_mnth    float64
# clnt_age            float64
# gendr                object
# num_accts           float64
# bal                 float64
# calls_6_mnth        float64
# logons_6_mnth       float64
# dtype: object

# %%
print(df_final_demo_clean['gendr'].unique())
df_final_demo_clean['gendr'] = df_final_demo_clean['gendr'].replace('X', 'U')
df_final_demo_clean['gendr']
# Out:
# ['U' 'M' 'F' 'X']
# 0        U
# 1        U
# 2        U
# 3        M
# 4        F
#         ..
# 70589    U
# 70590    M
# 70591    F
# 70592    M
# 70593    F
# Name: gendr, Length: 70594, dtype: object

# %%
df_final_demo_clean = cf.replace_age(df_final_demo_clean)
df_final_demo_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70589    7993686             4.0              56.0      38.5     U        3.0
# 70590    8981690            12.0             148.0      31.0     M        2.0
# 70591     333913            16.0             198.0      61.5     F        2.0
# 70592    1573142            21.0             255.0      68.0     M        3.0
# 70593    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df_final_demo_clean = cf.convert_num(df_final_demo_clean)
df_final_demo_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U          2
# 1        2304905             7.0              94.0      58.0     U          2
# 2        1439522             5.0              64.0      32.0     U          2
# 3        1562045            16.0             198.0      49.0     M          2
# 4        5126305            12.0             145.0      33.0     F          2
# ...          ...             ...               ...       ...   ...        ...
# 70589    7993686             4.0              56.0      38.5     U          3
# 70590    8981690            12.0             148.0      31.0     M          2
# 70591     333913            16.0             198.0      61.5     F          2
# 70592    1573142            21.0             255.0      68.0     M          3
# 70593    5602139            21.0             254.0      59.5     F          3
#
# ...

# %%
df_final_demo_clean = cf.convert_bal(df_final_demo_clean)
df_final_demo_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U          2
# 1        2304905             7.0              94.0      58.0     U          2
# 2        1439522             5.0              64.0      32.0     U          2
# 3        1562045            16.0             198.0      49.0     M          2
# 4        5126305            12.0             145.0      33.0     F          2
# ...          ...             ...               ...       ...   ...        ...
# 70589    7993686             4.0              56.0      38.5     U          3
# 70590    8981690            12.0             148.0      31.0     M          2
# 70591     333913            16.0             198.0      61.5     F          2
# 70592    1573142            21.0             255.0      68.0     M          3
# 70593    5602139            21.0             254.0      59.5     F          3
#
# ...

# %%
df_final_demo_clean['clnt_tenure_mnth'].min()
df_final_demo_clean['clnt_tenure_mnth'].mode()
# Out:
# 0    58.0
# Name: clnt_tenure_mnth, dtype: float64

# %%
df_final_demo_clean = cf.convert_tenure(df_final_demo_clean)
df_final_demo_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U          2
# 1        2304905             7.0              94.0      58.0     U          2
# 2        1439522             5.0              64.0      32.0     U          2
# 3        1562045            16.0             198.0      49.0     M          2
# 4        5126305            12.0             145.0      33.0     F          2
# ...          ...             ...               ...       ...   ...        ...
# 70589    7993686             4.0              56.0      38.5     U          3
# 70590    8981690            12.0             148.0      31.0     M          2
# 70591     333913            16.0             198.0      61.5     F          2
# 70592    1573142            21.0             255.0      68.0     M          3
# 70593    5602139            21.0             254.0      59.5     F          3
#
# ...

# %%
df_final_experiment_client = pd.read_csv("df_final_experiment_clients.txt", sep=",")
df_final_experiment_client
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_final_experiment_client.isnull().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
df_final_experiment_client = df_final_experiment_client.dropna()
df_final_experiment_client
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %%
df_final_experiment_client_clean = cf.handle_duplicates(df_final_experiment_client)
# Out:
# Number of duplicated rows before cleaning: 0
# Number of duplicated rows after cleaning: 0

# %%
df_final_web_data_pt1 = pd.read_csv("df_final_web_data_pt_1.txt", sep=",")
df_final_web_data_pt1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df_final_web_data_pt2 = pd.read_csv("df_final_web_data_pt_2.txt", sep=",")
df_final_web_data_pt2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
df_final_web_data = pd.concat([df_final_web_data_pt1, df_final_web_data_pt2], axis=0, join='inner')
df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
#df_final_web_data['date_time'] = pd.to_datetime(df_final_web_data['date_time'])
#df_final_web_data['time'] = df_final_web_data['date_time'].dt.strftime('%H:%M:%S')
#df_final_web_data['date'] = df_final_web_data['date_time'].dt.date
#df_final_web_data = df_final_web_data.drop('date_time', axis=1)
#df_final_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step      time        date
# 0            step_3  15:27:07  2017-04-17
# ...

# %%
df_final_web_data.isna().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# time            0
# date            0
# dtype: int64

# %%
df_final_web_data_clean = cf.handle_duplicates(df_final_web_data)
# Out:
# Number of duplicated rows before cleaning: 10764
# Number of duplicated rows after cleaning: 0

# %%
df_clean_all=cf.handle_merge(df_final_demo_clean, df_final_experiment_client_clean, df_final_web_data_clean)
df_clean_all
# Out:
#         client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0          836976             6.0              73.0      60.5     U
# 1          836976             6.0              73.0      60.5     U
# 2          836976             6.0              73.0      60.5     U
# 3          836976             6.0              73.0      60.5     U
# 4          836976             6.0              73.0      60.5     U
# ...           ...             ...               ...       ...   ...
# 317118    7468138            18.0             222.0      61.0     F
# 317119    7468138            18.0             222.0      61.0     F
# 317120    7468138            18.0             222.0      61.0     F
# 317121    7468138            18.0             222.0      61.0     F
# 317122    7468138            18.0             222.0      61.0     F
#
#         num_accts        bal  calls_6_mnth  logons_6_mnth generation  \
# 0               2   45105.30           6.0            9.0    boomers
# ...

# %%
busqueda = df_clean_all[df_clean_all['client_id']==836976]
busqueda.nunique()
# Out:
# client_id              1
# clnt_tenure_yr         1
# clnt_tenure_mnth       1
# clnt_age               1
# gendr                  1
# num_accts              1
# bal                    1
# calls_6_mnth           1
# logons_6_mnth          1
# generation             1
# testing_engagement     1
# balance_level          1
# tenure                 1
# Variation              1
# visitor_id             1
# visit_id               2
# process_step           5
# time                  11
# date                   2
# dtype: int64

# %%
busqueda_sorted = busqueda.sort_values(['time'])
busqueda_sorted
# Out:
#     client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 10     836976             6.0              73.0      60.5     U          2
# 9      836976             6.0              73.0      60.5     U          2
# 8      836976             6.0              73.0      60.5     U          2
# 7      836976             6.0              73.0      60.5     U          2
# 6      836976             6.0              73.0      60.5     U          2
# 5      836976             6.0              73.0      60.5     U          2
# 4      836976             6.0              73.0      60.5     U          2
# 3      836976             6.0              73.0      60.5     U          2
# 2      836976             6.0              73.0      60.5     U          2
# 1      836976             6.0              73.0      60.5     U          2
# 0      836976             6.0              73.0      60.5     U          2
#
# ...

# %%
#df_clean_all["repetition"] = df_clean_all.duplicated(subset=["visit_id", "process_step"], keep="last").astype(int)
#df_clean_all

# %%
#df_clean_all["first"] = df_clean_all.duplicated(subset=["visit_id", "process_step"], keep="first").astype(int)
#df_clean_all["last"] = df_clean_all.duplicated(subset=["visit_id", "process_step"], keep="last").astype(int)
#df_clean_all

# %%
df_clean_all.to_csv('df_clean_all.csv')
